# %%
# 1.Seris学习

# %% [markdown]
# # 1.Series学习

# %%
from random import random

import pandas as pd
s=pd.Series([11,12,13,14,15])
print(s)
# Out:
# 0    11
# 1    12
# 2    13
# 3    14
# 4    15
# dtype: int64

# %%
#自定义索引
s=pd.Series([11,12,13,14,15],index=['a','b','c','d','e'])
print(s)
# Out:
# a    11
# b    12
# c    13
# d    14
# e    15
# dtype: int64

# %%
# 定义name
s=pd.Series([11,12,13,14],index=['a','b','c','d'],name='元')
print(s)
# Out:
# a    11
# b    12
# c    13
# d    14
# Name: 元, dtype: int64

# %%
#通过字典来创建
s=pd.Series({'a':11,'b':12,'sadad':13,'d':14,'e':15})

# %%
print(s)
# Out:
# a        11
# b        12
# sadad    13
# d        14
# e        15
# dtype: int64

# %%
s1=pd.Series(s,index=['a','e'])
print(s1)
# Out:
# a    11
# e    15
# dtype: int64

# %%
# Series的属性
#自定义索引
s=pd.Series([11,12,13,14,15,16],index=['a','b','c','d','e','f'],name='data')
print(s)
# Out:
# a    11
# b    12
# c    13
# d    14
# e    15
# f    16
# Name: data, dtype: int64

# %%
print(s.index)
print(s.values)
print(s.shape,s.ndim,s.size)
print(s.dtype,s.name)
print(s.loc['a':'c'])
print(s.iloc[2])
print(s.at['c'])# 不支持切片
print(s.iat[2])
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')
# [11 12 13 14 15 16]
# (6,) 1 6
# int64 data
# a    11
# b    12
# c    13
# Name: data, dtype: int64
# 13
# 13
# 13

# %%
# series的访问数据
print(s['a'])
print(s[s>12])
# Out:
# 11
# c    13
# d    14
# e    15
# f    16
# Name: data, dtype: int64

# %%
print(s.head())# 前五行
print(s.tail())
# Out:
# a    11
# b    12
# c    13
# d    14
# e    15
# Name: data, dtype: int64
# b    12
# c    13
# d    14
# e    15
# f    16
# Name: data, dtype: int64

# %%
s=pd.Series([11,2,13,4,15,6,None],index=['a','b','c','d','e','f','g'],name='data')
s.head()
# Out:
# a    11.0
# b     2.0
# c    13.0
# d     4.0
# e    15.0
# Name: data, dtype: float64

# %%
# 查看des
s.describe()
# Out:
# count     6.000000
# mean      8.500000
# std       5.244044
# min       2.000000
# 25%       4.500000
# 50%       8.500000
# 75%      12.500000
# max      15.000000
# Name: data, dtype: float64

# %%
# 获取元素个数(忽略NaN)
print(s.count())
# Out:
# 6

# %%
s.keys() #和s.index一样获取索引
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g'], dtype='object')

# %%
s.isna()#检测series每一个元素是否为缺失值
# Out:
# a    False
# b    False
# c    False
# d    False
# e    False
# f    False
# g     True
# Name: data, dtype: bool

# %%
s.isin([2])
# Out:
# a    False
# b     True
# c    False
# d    False
# e    False
# f    False
# g    False
# Name: data, dtype: bool

# %%
print(s.mean())
# Out:
# 8.5

# %%
print(s.std())
# Out:
# 5.244044240850758

# %%
print(s.var())
print(s.max())
print(s.min())
print(s.median())
print(s.quantile(0.2))
# Out:
# 27.5
# 15.0
# 2.0
# 8.5
# 4.0

# %%
s.sort_values()
# Out:
# b     2.0
# d     4.0
# f     6.0
# a    11.0
# c    13.0
# e    15.0
# g     NaN
# Name: data, dtype: float64

# %%
s['h']=4
print(s.mode())
print(s.value_counts())
# Out:
# 0    4.0
# Name: data, dtype: float64
# data
# 4.0     2
# 11.0    1
# 2.0     1
# 13.0    1
# 15.0    1
# 6.0     1
# Name: count, dtype: int64

# %%
s.drop_duplicates()
# Out:
# a    11.0
# b     2.0
# c    13.0
# d     4.0
# e    15.0
# f     6.0
# g     NaN
# Name: data, dtype: float64

# %%
s.unique()
# Out:
# array([11.,  2., 13.,  4., 15.,  6., nan])

# %%
s.nunique()
# Out:
# 6

# %%
s.sort_index()
# Out:
# a    11.0
# b     2.0
# c    13.0
# d     4.0
# e    15.0
# f     6.0
# g     NaN
# h     4.0
# Name: data, dtype: float64

# %%
s.sort_values()
# Out:
# b     2.0
# d     4.0
# h     4.0
# f     6.0
# a    11.0
# c    13.0
# e    15.0
# g     NaN
# Name: data, dtype: float64

# %% [markdown]
# 创建一个包含10名学生数学成绩的Series,成绩范围在50-100之间。
# 计算平均分、最高分、最低分,并找出高于平均分的学生人数。

# %%
import numpy as np
np.random.seed(42)
scores=pd.Series(np.random.randint(50,101,10),index=['学生'+str(i) for i in range(1,11)])
scores
# Out:
# 学生1     88
# 学生2     78
# 学生3     64
# 学生4     92
# 学生5     57
# 学生6     70
# 学生7     88
# 学生8     68
# 学生9     72
# 学生10    60
# dtype: int32

# %%
print("平均数",scores.mean())
print("最高分",scores.max())
print("最低分",scores.min())
print("人数", scores[scores>scores.mean()].count())
#或者使用len()
print("人数",len(scores[scores>scores.mean()]))
# Out:
# 平均数 73.7
# 最高分 92
# 最低分 57
# 人数 4
# 人数 4

# %% [markdown]
# 给定某城市一周每天的最高温度Series,完成以下任务:
# 找出温度超过30度的天数
# 计算平均温度
# 将温度从高到低排序
# 找出温度变化最大的两天
#
# temperatures = pd.Series([28, 31, 29, 32, 30, 27, 33],
# index=['周一','周二','周三','周四','周五','周六',‘周日'])

# %%
temperatures=pd.Series([28,31,29,32,30,27,33],index=['周一','周二','周三','周四','周五','周六','周日'])
print(temperatures[temperatures>30].count())
print(temperatures.mean())
print(temperatures.sort_values(ascending=False))
# Out:
# 3
# 30.0
# 周日    33
# 周四    32
# 周二    31
# 周五    30
# 周三    29
# 周一    28
# 周六    27
# dtype: int64

# %%
t3=temperatures.diff().abs() #计算Series变换的值
t3
# Out:
# 周一    NaN
# 周二    3.0
# 周三    2.0
# 周四    3.0
# 周五    2.0
# 周六    3.0
# 周日    6.0
# dtype: float64

# %%
print(t3.sort_values(ascending=False).keys()[:2])
# Out:
# Index(['周日', '周二'], dtype='object')

# %% [markdown]
# 给定某股票连续10个交易日的收盘价Series:
# 计算每日收益率(当日收盘价/前日收盘价-1)
# 找出收益率最高和最低的日期
# 计算波动率(收益率的标准差)
#
# prices = pd.Series([102.3, 103.5, 105.1, 104.8,106.2,107.0,106.5,108.1,
# 109.3, 110.2], index=pd.date_range('2023-01-01', periods=10))

# %%
prices=pd.Series([102.3, 103.5, 105.1, 104.8,106.2,107.0,106.5,108.1,
109.3, 110.2],index=pd.date_range('2023-01-01',periods=10))
prices
# Out:
# 2023-01-01    102.3
# 2023-01-02    103.5
# 2023-01-03    105.1
# 2023-01-04    104.8
# 2023-01-05    106.2
# 2023-01-06    107.0
# 2023-01-07    106.5
# 2023-01-08    108.1
# 2023-01-09    109.3
# 2023-01-10    110.2
# Freq: D, dtype: float64

# %%
priceDiff=prices.pct_change()
priceDiff
# Out:
# 2023-01-01         NaN
# 2023-01-02    0.011730
# 2023-01-03    0.015459
# 2023-01-04   -0.002854
# 2023-01-05    0.013359
# 2023-01-06    0.007533
# 2023-01-07   -0.004673
# 2023-01-08    0.015023
# 2023-01-09    0.011101
# 2023-01-10    0.008234
# Freq: D, dtype: float64

# %%
print(priceDiff.argmax())
print(priceDiff.argmin())
print(priceDiff.var())
# Out:
# 2
# 6
# 5.437032861287789e-05
